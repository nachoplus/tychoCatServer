# %% [markdown]
# # Test to split mpcorb.sof file in chunks to speed up calculations

# %%
import tychoCatServer.helper as hlp
import pandas as pd

# %%
dic=hlp.read_sof_file('mpcorb.sof')

# %%
df=pd.DataFrame(dic).transpose()

# %%
df
# Out:
#                         Tp        Te          q         i         Om  \
# 1          20270713.533732  20250505   2.546423   10.5878   80.25221
# 2          20230307.358019  20250505   2.131552  34.92402   172.8953
# 3          20230402.336672  20250505   1.987119  12.98651  169.82994
# 4          20250814.428569  20250505   2.148619   7.14394  103.70297
# 5           20240508.04674  20250505   2.093772   5.35887  141.45353
# ...                    ...       ...        ...       ...        ...
# P/2025 C1   20250208.49084  20250209    2.74688   7.52434    9.11673
# C/2025 D1   20280518.31942  20231227  14.122774  84.50734  312.87576
# P/2025 D2   20280115.43327  20250216   7.226447   5.25648  255.20018
# P/2025 D3   20240726.00147  20250215   2.966608   9.64688  186.62995
# P/2025 D4   20250214.31782  20241008   3.254896  15.94137  233.11888
#
#                   om         e   rms   n_o    Tfirst     Tlast Perts  \
# ...
